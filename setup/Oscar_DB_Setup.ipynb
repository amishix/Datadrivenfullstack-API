# %% [markdown]
# #  Oscar Database Setup Notebook

# %%
import os
#  Confirm movies.db exists
from pathlib import Path

notebook_dir  = Path.cwd()               
apiserver_dir = notebook_dir.parent / "apiserver"

if not apiserver_dir.exists():
    raise FileNotFoundError(f"Could not find apiserver/ at {apiserver_dir!r}")

os.chdir(apiserver_dir)

# %% [markdown]
# ##  Step 2: Import key modules and database models

# %%
import subprocess

# Run the Oscar data loading script directly
result = subprocess.run(
    ["python3", "oscarsload.py"],
    capture_output=True,
    text=True
)
print(result.stdout)
if result.stderr:
    print("Errors in oscarsload.py:\n", result.stderr)

# Run the TMDB metadata enrichment script directly
result = subprocess.run(
    ["python3", "tmdbs4oscarsload.py"],
    capture_output=True,
    text=True
)
print(result.stdout)
if result.stderr:
    print("Errors in tmdbs4oscarsload.py:\n", result.stderr)
# Out:
# Oscar loader writing to: /Users/saba/Desktop/API/apiserver/movies.db
# Using movies.db at: /Users/saba/Desktop/API/apiserver/movies.db
# Starting Oscar data load.
# Loaded 11110 rows from CSV
# Skipped existing award: The Noose (1927), ACTOR, winner: False
# Skipped existing award: The Patent Leather Kid (1927), ACTOR, winner: False
# Skipped existing award: The Last Command (1927), ACTOR, winner: True
# Skipped existing award: The Way of All Flesh (1927), ACTOR, winner: True
# Skipped existing award: A Ship Comes In (1927), ACTRESS, winner: False
# Skipped existing award: 7th Heaven (1927), ACTRESS, winner: True
# Skipped existing award: Street Angel (1927), ACTRESS, winner: True
# Skipped existing award: Sunrise (1927), ACTRESS, winner: True
# Skipped existing award: Sadie Thompson (1927), ACTRESS, winner: False
# Skipped existing award: Sunrise (1927), ART DIRECTION, winner: False
# Skipped existing award: The Dove (1927), ART DIRECTION, winner: True
# Skipped existing award: Tempest (1927), ART DIRECTION, winner: True
# Skipped existing award: 7th Heaven (1927), ART DIRECTION, winner: False
# Skipped existing award: The Devil Dancer (1927), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Magic Flame (1927), CINEMATOGRAPHY, winner: False
# Skipped existing award: Sadie Thompson (1927), CINEMATOGRAPHY, winner: False
# Skipped existing award: Sunrise (1927), CINEMATOGRAPHY, winner: True
# Skipped existing award: Two Arabian Knights (1927), DIRECTING (Comedy Picture), winner: True
# Skipped existing award: Speedy (1927), DIRECTING (Comedy Picture), winner: False
# Skipped existing award: 7th Heaven (1927), DIRECTING (Dramatic Picture), winner: True
# Skipped existing award: Sorrell and Son (1927), DIRECTING (Dramatic Picture), winner: False
# Skipped existing award: The Crowd (1927), DIRECTING (Dramatic Picture), winner: False
# Skipped existing award: Wings (1927), ENGINEERING EFFECTS, winner: True
# Skipped existing award: The Racket (1927), OUTSTANDING PICTURE, winner: False
# Skipped existing award: 7th Heaven (1927), OUTSTANDING PICTURE, winner: False
# Skipped existing award: Wings (1927), OUTSTANDING PICTURE, winner: True
# Skipped existing award: Sunrise (1927), UNIQUE AND ARTISTIC PICTURE, winner: True
# Skipped existing award: The Crowd (1927), UNIQUE AND ARTISTIC PICTURE, winner: False
# Skipped existing award: Chang (1927), UNIQUE AND ARTISTIC PICTURE, winner: False
# Skipped existing award: The Jazz Singer (1927), WRITING (Adaptation), winner: False
# Skipped existing award: Glorious Betsy (1927), WRITING (Adaptation), winner: False
# Skipped existing award: 7th Heaven (1927), WRITING (Adaptation), winner: True
# Skipped existing award: The Last Command (1927), WRITING (Original Story), winner: False
# Skipped existing award: Underworld (1927), WRITING (Original Story), winner: True
# Skipped existing award: The Private Life of Helen of Troy (1927), WRITING (Title Writing), winner: False
# Skipped existing award: The Jazz Singer (1927), SPECIAL AWARD, winner: True
# Skipped existing award: The Circus (1927), SPECIAL AWARD, winner: True
# Skipped existing award: Thunderbolt (1928), ACTOR, winner: False
# Skipped existing award: In Old Arizona (1928), ACTOR, winner: True
# Skipped existing award: Alibi (1928), ACTOR, winner: False
# Skipped existing award: The Valiant (1928), ACTOR, winner: False
# Skipped existing award: The Patriot (1928), ACTOR, winner: False
# Skipped existing award: Madame X (1928), ACTRESS, winner: False
# Skipped existing award: The Barker (1928), ACTRESS, winner: False
# Skipped existing award: The Letter (1928), ACTRESS, winner: False
# Skipped existing award: The Divine Lady (1928), ACTRESS, winner: False
# Skipped existing award: The Broadway Melody (1928), ACTRESS, winner: False
# Skipped existing award: Coquette (1928), ACTRESS, winner: True
# Skipped existing award: The Patriot (1928), ART DIRECTION, winner: False
# Skipped existing award: The Bridge of San Luis Rey (1928), ART DIRECTION, winner: True
# Skipped existing award: Dynamite (1928), ART DIRECTION, winner: False
# Skipped existing award: Alibi (1928), ART DIRECTION, winner: False
# Skipped existing award: The Awakening (1928), ART DIRECTION, winner: False
# Skipped existing award: Street Angel (1928), ART DIRECTION, winner: False
# Skipped existing award: Our Dancing Daughters (1928), CINEMATOGRAPHY, winner: False
# Skipped existing award: White Shadows in the South Seas (1928), CINEMATOGRAPHY, winner: True
# Skipped existing award: In Old Arizona (1928), CINEMATOGRAPHY, winner: False
# Skipped existing award: Four Devils (1928), CINEMATOGRAPHY, winner: False
# Skipped existing award: Street Angel (1928), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Divine Lady (1928), CINEMATOGRAPHY, winner: False
# Skipped existing award: Madame X (1928), DIRECTING, winner: False
# Skipped existing award: The Broadway Melody (1928), DIRECTING, winner: False
# Skipped existing award: In Old Arizona (1928), DIRECTING, winner: False
# Skipped existing award: The Divine Lady (1928), DIRECTING, winner: True
# Skipped existing award: Drag (1928), DIRECTING, winner: False
# Skipped existing award: Weary River (1928), DIRECTING, winner: False
# Skipped existing award: The Patriot (1928), DIRECTING, winner: False
# Skipped existing award: Alibi (1928), OUTSTANDING PICTURE, winner: False
# Skipped existing award: In Old Arizona (1928), OUTSTANDING PICTURE, winner: False
# Skipped existing award: The Broadway Melody (1928), OUTSTANDING PICTURE, winner: True
# Skipped existing award: Hollywood Revue (1928), OUTSTANDING PICTURE, winner: False
# Skipped existing award: The Patriot (1928), OUTSTANDING PICTURE, winner: False
# Skipped existing award: In Old Arizona (1928), WRITING, winner: False
# Skipped existing award: The Valiant (1928), WRITING, winner: False
# Skipped existing award: The Cop (1928), WRITING, winner: False
# Skipped existing award: The Leatherneck (1928), WRITING, winner: False
# Skipped existing award: Sal of Singapore (1928), WRITING, winner: False
# Skipped existing award: Skyscraper (1928), WRITING, winner: False
# Skipped existing award: The Last of Mrs. Cheyney (1928), WRITING, winner: False
# Skipped existing award: The Patriot (1928), WRITING, winner: True
# Skipped existing award: Our Dancing Daughters (1928), WRITING, winner: False
# Skipped existing award: A Woman of Affairs (1928), WRITING, winner: False
# Skipped existing award: Wonder of Women (1928), WRITING, winner: False
# Skipped existing award: Disraeli (1929), ACTOR, winner: True
# Skipped existing award: The Green Goddess (1929), ACTOR, winner: False
# Skipped existing award: The Big House (1929), ACTOR, winner: False
# Skipped existing award: The Big Pond (1929), ACTOR, winner: False
# Skipped existing award: The Love Parade (1929), ACTOR, winner: False
# Skipped existing award: Bulldog Drummond (1929), ACTOR, winner: False
# Skipped existing award: Condemned (1929), ACTOR, winner: False
# Skipped existing award: The Rogue Song (1929), ACTOR, winner: False
# Skipped existing award: The Devil's Holiday (1929), ACTRESS, winner: False
# Skipped existing award: Sarah and Son (1929), ACTRESS, winner: False
# Skipped existing award: Anna Christie (1929), ACTRESS, winner: False
# Skipped existing award: Romance (1929), ACTRESS, winner: False
# Skipped existing award: The Divorcee (1929), ACTRESS, winner: True
# Skipped existing award: Their Own Desire (1929), ACTRESS, winner: False
# Skipped existing award: The Trespasser (1929), ACTRESS, winner: False
# Skipped existing award: Bulldog Drummond (1929), ART DIRECTION, winner: False
# Skipped existing award: King of Jazz (1929), ART DIRECTION, winner: True
# Skipped existing award: The Love Parade (1929), ART DIRECTION, winner: False
# Skipped existing award: Sally (1929), ART DIRECTION, winner: False
# Skipped existing award: The Vagabond King (1929), ART DIRECTION, winner: False
# Skipped existing award: All Quiet on the Western Front (1929), CINEMATOGRAPHY, winner: False
# Skipped existing award: Anna Christie (1929), CINEMATOGRAPHY, winner: False
# Skipped existing award: Hell's Angels (1929), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Love Parade (1929), CINEMATOGRAPHY, winner: False
# Skipped existing award: With Byrd at the South Pole (1929), CINEMATOGRAPHY, winner: True
# Skipped existing award: Anna Christie (1929), DIRECTING, winner: False
# Skipped existing award: Romance (1929), DIRECTING, winner: False
# Skipped existing award: The Divorcee (1929), DIRECTING, winner: False
# Skipped existing award: The Love Parade (1929), DIRECTING, winner: False
# Skipped existing award: All Quiet on the Western Front (1929), DIRECTING, winner: True
# Skipped existing award: Hallelujah (1929), DIRECTING, winner: False
# Skipped existing award: All Quiet on the Western Front (1929), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: The Big House (1929), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Disraeli (1929), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Divorcee (1929), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Love Parade (1929), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Big House (1929), SOUND RECORDING, winner: True
# Skipped existing award: The Case of Sergeant Grischa (1929), SOUND RECORDING, winner: False
# Skipped existing award: The Love Parade (1929), SOUND RECORDING, winner: False
# Skipped existing award: Raffles (1929), SOUND RECORDING, winner: False
# Skipped existing award: Song of the Flame (1929), SOUND RECORDING, winner: False
# Skipped existing award: All Quiet on the Western Front (1929), WRITING, winner: False
# Skipped existing award: The Big House (1929), WRITING, winner: True
# Skipped existing award: Disraeli (1929), WRITING, winner: False
# Skipped existing award: The Divorcee (1929), WRITING, winner: False
# Skipped existing award: Street of Chance (1929), WRITING, winner: False
# Skipped existing award: A Free Soul (1930), ACTOR, winner: True
# Skipped existing award: Skippy (1930), ACTOR, winner: False
# Skipped existing award: Cimarron (1930), ACTOR, winner: False
# Skipped existing award: The Royal Family of Broadway (1930), ACTOR, winner: False
# Skipped existing award: The Front Page (1930), ACTOR, winner: False
# Skipped existing award: Morocco (1930), ACTRESS, winner: False
# Skipped existing award: Min and Bill (1930), ACTRESS, winner: True
# Skipped existing award: Cimarron (1930), ACTRESS, winner: False
# Skipped existing award: Holiday (1930), ACTRESS, winner: False
# Skipped existing award: A Free Soul (1930), ACTRESS, winner: False
# Skipped existing award: Cimarron (1930), ART DIRECTION, winner: True
# Skipped existing award: Just Imagine (1930), ART DIRECTION, winner: False
# Skipped existing award: Morocco (1930), ART DIRECTION, winner: False
# Skipped existing award: Svengali (1930), ART DIRECTION, winner: False
# Skipped existing award: Whoopee! (1930), ART DIRECTION, winner: False
# Skipped existing award: Cimarron (1930), CINEMATOGRAPHY, winner: False
# Skipped existing award: Morocco (1930), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Right to Love (1930), CINEMATOGRAPHY, winner: False
# Skipped existing award: Svengali (1930), CINEMATOGRAPHY, winner: False
# Skipped existing award: Tabu (1930), CINEMATOGRAPHY, winner: True
# Skipped existing award: Cimarron (1930), DIRECTING, winner: False
# Skipped existing award: A Free Soul (1930), DIRECTING, winner: False
# Skipped existing award: The Front Page (1930), DIRECTING, winner: False
# Skipped existing award: Morocco (1930), DIRECTING, winner: False
# Skipped existing award: Skippy (1930), DIRECTING, winner: True
# Skipped existing award: Cimarron (1930), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: East Lynne (1930), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Front Page (1930), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Skippy (1930), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Trader Horn (1930), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Cimarron (1930), WRITING (Adaptation), winner: True
# Skipped existing award: The Criminal Code (1930), WRITING (Adaptation), winner: False
# Skipped existing award: Holiday (1930), WRITING (Adaptation), winner: False
# Skipped existing award: Little Caesar (1930), WRITING (Adaptation), winner: False
# Skipped existing award: Skippy (1930), WRITING (Adaptation), winner: False
# Skipped existing award: The Dawn Patrol (1930), WRITING (Original Story), winner: True
# Skipped existing award: The Doorway to Hell (1930), WRITING (Original Story), winner: False
# Skipped existing award: Laughter (1930), WRITING (Original Story), winner: False
# Skipped existing award: The Public Enemy (1930), WRITING (Original Story), winner: False
# Skipped existing award: Smart Money (1930), WRITING (Original Story), winner: False
# Skipped existing award: The Champ (1931), ACTOR, winner: True
# Skipped existing award: The Guardsman (1931), ACTOR, winner: False
# Skipped existing award: Dr. Jekyll and Mr. Hyde (1931), ACTOR, winner: True
# Skipped existing award: Emma (1931), ACTRESS, winner: False
# Skipped existing award: The Guardsman (1931), ACTRESS, winner: False
# Skipped existing award: The Sin of Madelon Claudet (1931), ACTRESS, winner: True
# Skipped existing award: Arrowsmith (1931), ART DIRECTION, winner: False
# Skipped existing award: Transatlantic (1931), ART DIRECTION, winner: True
# Skipped existing award: Arrowsmith (1931), CINEMATOGRAPHY, winner: False
# Skipped existing award: Dr. Jekyll and Mr. Hyde (1931), CINEMATOGRAPHY, winner: False
# Skipped existing award: Shanghai Express (1931), CINEMATOGRAPHY, winner: True
# Skipped existing award: Bad Girl (1931), DIRECTING, winner: True
# Skipped existing award: The Champ (1931), DIRECTING, winner: False
# Skipped existing award: Shanghai Express (1931), DIRECTING, winner: False
# Skipped existing award: Arrowsmith (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Bad Girl (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Champ (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Five Star Final (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Grand Hotel (1931), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: One Hour with You (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Shanghai Express (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Smiling Lieutenant (1931), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Flowers and Trees (1931), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: It's Got Me Again (1931), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: Mickey's Orphans (1931), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Loud Mouth (1931), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: The Music Box (1931), SHORT SUBJECT (Comedy), winner: True
# Skipped existing award: Scratch-As-Catch-Can (1931), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: Stout Hearts and Willing Hands (1931), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: Screen Souvenirs (1931), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: Swing High (1931), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: Wrestling Swordfish (1931), SHORT SUBJECT (Novelty), winner: True
# Skipped existing award: Arrowsmith (1931), WRITING (Adaptation), winner: False
# Skipped existing award: Bad Girl (1931), WRITING (Adaptation), winner: True
# Skipped existing award: Dr. Jekyll and Mr. Hyde (1931), WRITING (Adaptation), winner: False
# Skipped existing award: The Champ (1931), WRITING (Original Story), winner: True
# Skipped existing award: Lady and Gent (1931), WRITING (Original Story), winner: False
# Skipped existing award: The Star Witness (1931), WRITING (Original Story), winner: False
# Skipped existing award: What Price Hollywood? (1931), WRITING (Original Story), winner: False
# Skipped existing award: Berkeley Square (1932), ACTOR, winner: False
# Skipped existing award: The Private Life of Henry VIII (1932), ACTOR, winner: True
# Skipped existing award: I Am a Fugitive from a Chain Gang (1932), ACTOR, winner: False
# Skipped existing award: Morning Glory (1932), ACTRESS, winner: True
# Skipped existing award: Lady for a Day (1932), ACTRESS, winner: False
# Skipped existing award: Cavalcade (1932), ACTRESS, winner: False
# Skipped existing award: Cavalcade (1932), ART DIRECTION, winner: True
# Skipped existing award: A Farewell to Arms (1932), ART DIRECTION, winner: False
# Skipped existing award: When Ladies Meet (1932), ART DIRECTION, winner: False
# Skipped existing award: A Farewell to Arms (1932), CINEMATOGRAPHY, winner: True
# Skipped existing award: Reunion in Vienna (1932), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Sign of the Cross (1932), CINEMATOGRAPHY, winner: False
# Skipped existing award: Cavalcade (1932), DIRECTING, winner: True
# Skipped existing award: Lady for a Day (1932), DIRECTING, winner: False
# Skipped existing award: Little Women (1932), DIRECTING, winner: False
# Skipped existing award: Cavalcade (1932), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: A Farewell to Arms (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: 42nd Street (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: I Am a Fugitive from a Chain Gang (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Lady for a Day (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Little Women (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Private Life of Henry VIII (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: She Done Him Wrong (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Smilin' Through (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: State Fair (1932), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Building a Building (1932), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Merry Old Soul (1932), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Three Little Pigs (1932), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: Mister Mugg (1932), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: A Preferred List (1932), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: So This Is Harris (1932), SHORT SUBJECT (Comedy), winner: True
# Skipped existing award: Krakatoa (1932), SHORT SUBJECT (Novelty), winner: True
# Skipped existing award: Menu (1932), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: The Sea (1932), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: A Farewell to Arms (1932), SOUND RECORDING, winner: True
# Skipped existing award: 42nd Street (1932), SOUND RECORDING, winner: False
# Skipped existing award: Gold Diggers of 1933 (1932), SOUND RECORDING, winner: False
# Skipped existing award: I Am a Fugitive from a Chain Gang (1932), SOUND RECORDING, winner: False
# Skipped existing award: Lady for a Day (1932), WRITING (Adaptation), winner: False
# Skipped existing award: Little Women (1932), WRITING (Adaptation), winner: True
# Skipped existing award: State Fair (1932), WRITING (Adaptation), winner: False
# Skipped existing award: One Way Passage (1932), WRITING (Original Story), winner: True
# Skipped existing award: The Prizefighter and the Lady (1932), WRITING (Original Story), winner: False
# Skipped existing award: Rasputin and the Empress (1932), WRITING (Original Story), winner: False
# Skipped existing award: It Happened One Night (1934), ACTOR, winner: True
# Skipped existing award: The Affairs of Cellini (1934), ACTOR, winner: False
# Skipped existing award: The Thin Man (1934), ACTOR, winner: False
# Skipped existing award: It Happened One Night (1934), ACTRESS, winner: True
# Skipped existing award: Of Human Bondage (1934), ACTRESS, winner: False
# Skipped existing award: One Night of Love (1934), ACTRESS, winner: False
# Skipped existing award: The Barretts of Wimpole Street (1934), ACTRESS, winner: False
# Skipped existing award: The Affairs of Cellini (1934), ART DIRECTION, winner: False
# Skipped existing award: The Gay Divorcee (1934), ART DIRECTION, winner: False
# Skipped existing award: The Merry Widow (1934), ART DIRECTION, winner: True
# Skipped existing award: Cleopatra (1934), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Imitation of Life (1934), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Viva Villa! (1934), ASSISTANT DIRECTOR, winner: True
# Skipped existing award: The Affairs of Cellini (1934), CINEMATOGRAPHY, winner: False
# Skipped existing award: Cleopatra (1934), CINEMATOGRAPHY, winner: True
# Skipped existing award: Operator 13 (1934), CINEMATOGRAPHY, winner: False
# Skipped existing award: It Happened One Night (1934), DIRECTING, winner: True
# Skipped existing award: One Night of Love (1934), DIRECTING, winner: False
# Skipped existing award: The Thin Man (1934), DIRECTING, winner: False
# Skipped existing award: Cleopatra (1934), FILM EDITING, winner: False
# Skipped existing award: Eskimo (1934), FILM EDITING, winner: True
# Skipped existing award: One Night of Love (1934), FILM EDITING, winner: False
# Skipped existing award: The Gay Divorcee (1934), MUSIC (Scoring), winner: False
# Skipped existing award: The Lost Patrol (1934), MUSIC (Scoring), winner: False
# Skipped existing award: One Night of Love (1934), MUSIC (Scoring), winner: True
# Skipped existing award: Flying Down to Rio (1934), MUSIC (Song), winner: False
# Skipped existing award: The Gay Divorcee (1934), MUSIC (Song), winner: True
# Skipped existing award: She Loves Me Not (1934), MUSIC (Song), winner: False
# Skipped existing award: The Barretts of Wimpole Street (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Cleopatra (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Flirtation Walk (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Gay Divorcee (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Here Comes the Navy (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The House of Rothschild (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Imitation of Life (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: It Happened One Night (1934), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: One Night of Love (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Thin Man (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Viva Villa! (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The White Parade (1934), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Holiday Land (1934), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: Jolly Little Elves (1934), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Tortoise and the Hare (1934), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: La Cucaracha (1934), SHORT SUBJECT (Comedy), winner: True
# Skipped existing award: Men in Black (1934), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: What, No Men! (1934), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: Bosom Friends (1934), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: City of Wax (1934), SHORT SUBJECT (Novelty), winner: True
# Skipped existing award: Strikes and Spares (1934), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: The Affairs of Cellini (1934), SOUND RECORDING, winner: False
# Skipped existing award: Cleopatra (1934), SOUND RECORDING, winner: False
# Skipped existing award: Flirtation Walk (1934), SOUND RECORDING, winner: False
# Skipped existing award: The Gay Divorcee (1934), SOUND RECORDING, winner: False
# Skipped existing award: Imitation of Life (1934), SOUND RECORDING, winner: False
# Skipped existing award: One Night of Love (1934), SOUND RECORDING, winner: True
# Skipped existing award: Viva Villa! (1934), SOUND RECORDING, winner: False
# Skipped existing award: The White Parade (1934), SOUND RECORDING, winner: False
# Skipped existing award: It Happened One Night (1934), WRITING (Adaptation), winner: True
# Skipped existing award: The Thin Man (1934), WRITING (Adaptation), winner: False
# Skipped existing award: Viva Villa! (1934), WRITING (Adaptation), winner: False
# Skipped existing award: Hide-Out (1934), WRITING (Original Story), winner: False
# Skipped existing award: Manhattan Melodrama (1934), WRITING (Original Story), winner: True
# Skipped existing award: The Richest Girl in the World (1934), WRITING (Original Story), winner: False
# Skipped existing award: Mutiny on the Bounty (1935), ACTOR, winner: False
# Skipped existing award: Mutiny on the Bounty (1935), ACTOR, winner: False
# Skipped existing award: The Informer (1935), ACTOR, winner: True
# Skipped existing award: Black Fury (1935), ACTOR, winner: False
# Skipped existing award: Mutiny on the Bounty (1935), ACTOR, winner: False
# Skipped existing award: Escape Me Never (1935), ACTRESS, winner: False
# Skipped existing award: Private Worlds (1935), ACTRESS, winner: False
# Skipped existing award: Dangerous (1935), ACTRESS, winner: True
# Skipped existing award: Alice Adams (1935), ACTRESS, winner: False
# Skipped existing award: Becky Sharp (1935), ACTRESS, winner: False
# Skipped existing award: The Dark Angel (1935), ACTRESS, winner: False
# Skipped existing award: The Dark Angel (1935), ART DIRECTION, winner: True
# Skipped existing award: The Lives of a Bengal Lancer (1935), ART DIRECTION, winner: False
# Skipped existing award: Top Hat (1935), ART DIRECTION, winner: False
# Skipped existing award: David Copperfield (1935), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Les Miserables (1935), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: The Lives of a Bengal Lancer (1935), ASSISTANT DIRECTOR, winner: True
# Skipped existing award: A Midsummer Night's Dream (1935), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Barbary Coast (1935), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Crusades (1935), CINEMATOGRAPHY, winner: False
# Skipped existing award: Les Miserables (1935), CINEMATOGRAPHY, winner: False
# Skipped existing award: A Midsummer Night's Dream (1935), CINEMATOGRAPHY, winner: True
# Skipped existing award: Gold Diggers of 1935 (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Go into Your Dance (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Broadway Hostess (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Broadway Melody of 1936 (1935), DANCE DIRECTION, winner: True
# Skipped existing award: Folies Bergere (1935), DANCE DIRECTION, winner: True
# Skipped existing award: King of Burlesque (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Top Hat (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Big Broadcast of 1936 (1935), DANCE DIRECTION, winner: False
# Skipped existing award: All the King's Horses (1935), DANCE DIRECTION, winner: False
# Skipped existing award: She (1935), DANCE DIRECTION, winner: False
# Skipped existing award: Captain Blood (1935), DIRECTING, winner: False
# Skipped existing award: The Informer (1935), DIRECTING, winner: True
# Skipped existing award: The Lives of a Bengal Lancer (1935), DIRECTING, winner: False
# Skipped existing award: Mutiny on the Bounty (1935), DIRECTING, winner: False
# Skipped existing award: David Copperfield (1935), FILM EDITING, winner: False
# Skipped existing award: The Informer (1935), FILM EDITING, winner: False
# Skipped existing award: Les Miserables (1935), FILM EDITING, winner: False
# Skipped existing award: The Lives of a Bengal Lancer (1935), FILM EDITING, winner: False
# Skipped existing award: A Midsummer Night's Dream (1935), FILM EDITING, winner: True
# Skipped existing award: Mutiny on the Bounty (1935), FILM EDITING, winner: False
# Skipped existing award: Captain Blood (1935), MUSIC (Scoring), winner: False
# Skipped existing award: The Informer (1935), MUSIC (Scoring), winner: True
# Skipped existing award: Mutiny on the Bounty (1935), MUSIC (Scoring), winner: False
# Skipped existing award: Peter Ibbetson (1935), MUSIC (Scoring), winner: False
# Skipped existing award: Top Hat (1935), MUSIC (Song), winner: False
# Skipped existing award: Roberta (1935), MUSIC (Song), winner: False
# Skipped existing award: Gold Diggers of 1935 (1935), MUSIC (Song), winner: True
# Skipped existing award: Alice Adams (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Broadway Melody of 1936 (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Captain Blood (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: David Copperfield (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Informer (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Les Miserables (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Lives of a Bengal Lancer (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: A Midsummer Night's Dream (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Mutiny on the Bounty (1935), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: Naughty Marietta (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Ruggles of Red Gap (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Top Hat (1935), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Calico Dragon (1935), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: Three Orphan Kittens (1935), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: Who Killed Cock Robin? (1935), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: How to Sleep (1935), SHORT SUBJECT (Comedy), winner: True
# Skipped existing award: Oh, My Nerves (1935), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: Tit for Tat (1935), SHORT SUBJECT (Comedy), winner: False
# Skipped existing award: Audioscopiks (1935), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: Camera Thrills (1935), SHORT SUBJECT (Novelty), winner: False
# Skipped existing award: Wings over Mt. Everest (1935), SHORT SUBJECT (Novelty), winner: True
# Skipped existing award: Bride of Frankenstein (1935), SOUND RECORDING, winner: False
# Skipped existing award: Captain Blood (1935), SOUND RECORDING, winner: False
# Skipped existing award: The Dark Angel (1935), SOUND RECORDING, winner: False
# Skipped existing award: I Dream Too Much (1935), SOUND RECORDING, winner: False
# Skipped existing award: The Lives of a Bengal Lancer (1935), SOUND RECORDING, winner: False
# Skipped existing award: Love Me Forever (1935), SOUND RECORDING, winner: False
# Skipped existing award: Naughty Marietta (1935), SOUND RECORDING, winner: True
# Skipped existing award: $1,000 a Minute (1935), SOUND RECORDING, winner: False
# Skipped existing award: Thanks a Million (1935), SOUND RECORDING, winner: False
# Skipped existing award: Broadway Melody of 1936 (1935), WRITING (Original Story), winner: False
# Skipped existing award: G-Men (1935), WRITING (Original Story), winner: False
# Skipped existing award: The Gay Deception (1935), WRITING (Original Story), winner: False
# Skipped existing award: The Scoundrel (1935), WRITING (Original Story), winner: True
# Skipped existing award: Captain Blood (1935), WRITING (Screenplay), winner: False
# Skipped existing award: The Informer (1935), WRITING (Screenplay), winner: True
# Skipped existing award: The Lives of a Bengal Lancer (1935), WRITING (Screenplay), winner: False
# Skipped existing award: Mutiny on the Bounty (1935), WRITING (Screenplay), winner: False
# Skipped existing award: Mr. Deeds Goes to Town (1936), ACTOR, winner: False
# Skipped existing award: Dodsworth (1936), ACTOR, winner: False
# Skipped existing award: The Story of Louis Pasteur (1936), ACTOR, winner: True
# Skipped existing award: My Man Godfrey (1936), ACTOR, winner: False
# Skipped existing award: San Francisco (1936), ACTOR, winner: False
# Skipped existing award: My Man Godfrey (1936), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Come and Get It (1936), ACTOR IN A SUPPORTING ROLE, winner: True
# Skipped existing award: Pigskin Parade (1936), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Romeo and Juliet (1936), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: The General Died at Dawn (1936), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Theodora Goes Wild (1936), ACTRESS, winner: False
# Skipped existing award: Valiant Is the Word for Carrie (1936), ACTRESS, winner: False
# Skipped existing award: My Man Godfrey (1936), ACTRESS, winner: False
# Skipped existing award: The Great Ziegfeld (1936), ACTRESS, winner: True
# Skipped existing award: Romeo and Juliet (1936), ACTRESS, winner: False
# Skipped existing award: The Gorgeous Hussy (1936), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: My Man Godfrey (1936), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: These Three (1936), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Dodsworth (1936), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Anthony Adverse (1936), ACTRESS IN A SUPPORTING ROLE, winner: True
# Skipped existing award: Anthony Adverse (1936), ART DIRECTION, winner: False
# Skipped existing award: Dodsworth (1936), ART DIRECTION, winner: True
# Skipped existing award: The Great Ziegfeld (1936), ART DIRECTION, winner: False
# Skipped existing award: Lloyds of London (1936), ART DIRECTION, winner: False
# Skipped existing award: The Magnificent Brute (1936), ART DIRECTION, winner: False
# Skipped existing award: Romeo and Juliet (1936), ART DIRECTION, winner: False
# Skipped existing award: Winterset (1936), ART DIRECTION, winner: False
# Skipped existing award: Anthony Adverse (1936), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: The Charge of the Light Brigade (1936), ASSISTANT DIRECTOR, winner: True
# Skipped existing award: The Garden of Allah (1936), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: The Last of the Mohicans (1936), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: San Francisco (1936), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Anthony Adverse (1936), CINEMATOGRAPHY, winner: True
# Skipped existing award: The General Died at Dawn (1936), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Gorgeous Hussy (1936), CINEMATOGRAPHY, winner: False
# Skipped existing award: Gold Diggers of 1937 (1936), DANCE DIRECTION, winner: False
# Skipped existing award: Cain and Mabel (1936), DANCE DIRECTION, winner: False
# Skipped existing award: The Great Ziegfeld (1936), DANCE DIRECTION, winner: True
# Skipped existing award: Born to Dance (1936), DANCE DIRECTION, winner: False
# Skipped existing award: One in a Million (1936), DANCE DIRECTION, winner: False
# Skipped existing award: Dancing Pirate (1936), DANCE DIRECTION, winner: False
# Skipped existing award: Swing Time (1936), DANCE DIRECTION, winner: False
# Skipped existing award: Dodsworth (1936), DIRECTING, winner: False
# Skipped existing award: The Great Ziegfeld (1936), DIRECTING, winner: False
# Skipped existing award: Mr. Deeds Goes to Town (1936), DIRECTING, winner: True
# Skipped existing award: My Man Godfrey (1936), DIRECTING, winner: False
# Skipped existing award: San Francisco (1936), DIRECTING, winner: False
# Skipped existing award: Anthony Adverse (1936), FILM EDITING, winner: True
# Skipped existing award: Come and Get It (1936), FILM EDITING, winner: False
# Skipped existing award: The Great Ziegfeld (1936), FILM EDITING, winner: False
# Skipped existing award: Lloyds of London (1936), FILM EDITING, winner: False
# Skipped existing award: A Tale of Two Cities (1936), FILM EDITING, winner: False
# Skipped existing award: Theodora Goes Wild (1936), FILM EDITING, winner: False
# Skipped existing award: Anthony Adverse (1936), MUSIC (Scoring), winner: True
# Skipped existing award: The Charge of the Light Brigade (1936), MUSIC (Scoring), winner: False
# Skipped existing award: The Garden of Allah (1936), MUSIC (Scoring), winner: False
# Skipped existing award: The General Died at Dawn (1936), MUSIC (Scoring), winner: False
# Skipped existing award: Winterset (1936), MUSIC (Scoring), winner: False
# Skipped existing award: Suzy (1936), MUSIC (Song), winner: False
# Skipped existing award: Born to Dance (1936), MUSIC (Song), winner: False
# Skipped existing award: Trail of the Lonesome Pine (1936), MUSIC (Song), winner: False
# Skipped existing award: Pennies from Heaven (1936), MUSIC (Song), winner: False
# Skipped existing award: Swing Time (1936), MUSIC (Song), winner: True
# Skipped existing award: Sing, Baby, Sing (1936), MUSIC (Song), winner: False
# Skipped existing award: Anthony Adverse (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Dodsworth (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Great Ziegfeld (1936), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: Libeled Lady (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Mr. Deeds Goes to Town (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Romeo and Juliet (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: San Francisco (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Story of Louis Pasteur (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: A Tale of Two Cities (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Three Smart Girls (1936), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Country Cousin (1936), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: Old Mill Pond (1936), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: Sinbad the Sailor (1936), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: Give Me Liberty (1936), SHORT SUBJECT (Color), winner: True
# Skipped existing award: La Fiesta de Santa Barbara (1936), SHORT SUBJECT (Color), winner: False
# Skipped existing award: Popular Science J-6-2 (1936), SHORT SUBJECT (Color), winner: False
# Skipped existing award: Bored of Education (1936), SHORT SUBJECT (One-reel), winner: True
# Skipped existing award: Moscow Moods (1936), SHORT SUBJECT (One-reel), winner: False
# Skipped existing award: Wanted, a Master (1936), SHORT SUBJECT (One-reel), winner: False
# Skipped existing award: Double or Nothing (1936), SHORT SUBJECT (Two-reel), winner: False
# Skipped existing award: Dummy Ache (1936), SHORT SUBJECT (Two-reel), winner: False
# Skipped existing award: The Public Pays (1936), SHORT SUBJECT (Two-reel), winner: True
# Skipped existing award: Banjo on My Knee (1936), SOUND RECORDING, winner: False
# Skipped existing award: The Charge of the Light Brigade (1936), SOUND RECORDING, winner: False
# Skipped existing award: Dodsworth (1936), SOUND RECORDING, winner: False
# Skipped existing award: General Spanky (1936), SOUND RECORDING, winner: False
# Skipped existing award: Mr. Deeds Goes to Town (1936), SOUND RECORDING, winner: False
# Skipped existing award: San Francisco (1936), SOUND RECORDING, winner: True
# Skipped existing award: The Texas Rangers (1936), SOUND RECORDING, winner: False
# Skipped existing award: That Girl from Paris (1936), SOUND RECORDING, winner: False
# Skipped existing award: Three Smart Girls (1936), SOUND RECORDING, winner: False
# Skipped existing award: Fury (1936), WRITING (Original Story), winner: False
# Skipped existing award: The Great Ziegfeld (1936), WRITING (Original Story), winner: False
# Skipped existing award: San Francisco (1936), WRITING (Original Story), winner: False
# Skipped existing award: The Story of Louis Pasteur (1936), WRITING (Original Story), winner: True
# Skipped existing award: Three Smart Girls (1936), WRITING (Original Story), winner: False
# Skipped existing award: After the Thin Man (1936), WRITING (Screenplay), winner: False
# Skipped existing award: Dodsworth (1936), WRITING (Screenplay), winner: False
# Skipped existing award: Mr. Deeds Goes to Town (1936), WRITING (Screenplay), winner: False
# Skipped existing award: My Man Godfrey (1936), WRITING (Screenplay), winner: False
# Skipped existing award: The Story of Louis Pasteur (1936), WRITING (Screenplay), winner: True
# Skipped existing award: The March of Time (1936), SPECIAL AWARD, winner: True
# Skipped existing award: The Garden of Allah (1936), SPECIAL AWARD, winner: True
# Skipped existing award: Conquest (1937), ACTOR, winner: False
# Skipped existing award: A Star Is Born (1937), ACTOR, winner: False
# Skipped existing award: Night Must Fall (1937), ACTOR, winner: False
# Skipped existing award: The Life of Emile Zola (1937), ACTOR, winner: False
# Skipped existing award: Captains Courageous (1937), ACTOR, winner: True
# Skipped existing award: The Awful Truth (1937), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: The Hurricane (1937), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: The Life of Emile Zola (1937), ACTOR IN A SUPPORTING ROLE, winner: True
# Skipped existing award: Lost Horizon (1937), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Topper (1937), ACTOR IN A SUPPORTING ROLE, winner: False
# Skipped existing award: The Awful Truth (1937), ACTRESS, winner: False
# Skipped existing award: Camille (1937), ACTRESS, winner: False
# Skipped existing award: A Star Is Born (1937), ACTRESS, winner: False
# Skipped existing award: The Good Earth (1937), ACTRESS, winner: True
# Skipped existing award: Stella Dallas (1937), ACTRESS, winner: False
# Skipped existing award: In Old Chicago (1937), ACTRESS IN A SUPPORTING ROLE, winner: True
# Skipped existing award: Stage Door (1937), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Stella Dallas (1937), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Dead End (1937), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Night Must Fall (1937), ACTRESS IN A SUPPORTING ROLE, winner: False
# Skipped existing award: Conquest (1937), ART DIRECTION, winner: False
# Skipped existing award: A Damsel in Distress (1937), ART DIRECTION, winner: False
# Skipped existing award: Dead End (1937), ART DIRECTION, winner: False
# Skipped existing award: Every Day's a Holiday (1937), ART DIRECTION, winner: False
# Skipped existing award: The Life of Emile Zola (1937), ART DIRECTION, winner: False
# Skipped existing award: Lost Horizon (1937), ART DIRECTION, winner: True
# Skipped existing award: Manhattan Merry-Go-Round (1937), ART DIRECTION, winner: False
# Skipped existing award: The Prisoner of Zenda (1937), ART DIRECTION, winner: False
# Skipped existing award: Souls at Sea (1937), ART DIRECTION, winner: False
# Skipped existing award: Walter Wanger's Vogues of 1938 (1937), ART DIRECTION, winner: False
# Skipped existing award: Wee Willie Winkie (1937), ART DIRECTION, winner: False
# Skipped existing award: You're a Sweetheart (1937), ART DIRECTION, winner: False
# Skipped existing award: In Old Chicago (1937), ASSISTANT DIRECTOR, winner: True
# Skipped existing award: The Life of Emile Zola (1937), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Lost Horizon (1937), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Souls at Sea (1937), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: A Star Is Born (1937), ASSISTANT DIRECTOR, winner: False
# Skipped existing award: Dead End (1937), CINEMATOGRAPHY, winner: False
# Skipped existing award: The Good Earth (1937), CINEMATOGRAPHY, winner: True
# Skipped existing award: Wings over Honolulu (1937), CINEMATOGRAPHY, winner: False
# Skipped existing award: Varsity Show (1937), DANCE DIRECTION, winner: False
# Skipped existing award: Ready, Willing and Able (1937), DANCE DIRECTION, winner: False
# Skipped existing award: A Day at the Races (1937), DANCE DIRECTION, winner: False
# Skipped existing award: Ali Baba Goes to Town (1937), DANCE DIRECTION, winner: False
# Skipped existing award: Thin Ice (1937), DANCE DIRECTION, winner: False
# Skipped existing award: A Damsel in Distress (1937), DANCE DIRECTION, winner: True
# Skipped existing award: Waikiki Wedding (1937), DANCE DIRECTION, winner: False
# Skipped existing award: The Awful Truth (1937), DIRECTING, winner: True
# Skipped existing award: The Good Earth (1937), DIRECTING, winner: False
# Skipped existing award: The Life of Emile Zola (1937), DIRECTING, winner: False
# Skipped existing award: Stage Door (1937), DIRECTING, winner: False
# Skipped existing award: A Star Is Born (1937), DIRECTING, winner: False
# Skipped existing award: The Awful Truth (1937), FILM EDITING, winner: False
# Skipped existing award: Captains Courageous (1937), FILM EDITING, winner: False
# Skipped existing award: The Good Earth (1937), FILM EDITING, winner: False
# Skipped existing award: Lost Horizon (1937), FILM EDITING, winner: True
# Skipped existing award: One Hundred Men and a Girl (1937), FILM EDITING, winner: False
# Skipped existing award: The Hurricane (1937), MUSIC (Scoring), winner: False
# Skipped existing award: In Old Chicago (1937), MUSIC (Scoring), winner: False
# Skipped existing award: The Life of Emile Zola (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Lost Horizon (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Make a Wish (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Maytime (1937), MUSIC (Scoring), winner: False
# Skipped existing award: One Hundred Men and a Girl (1937), MUSIC (Scoring), winner: True
# Skipped existing award: Portia on Trial (1937), MUSIC (Scoring), winner: False
# Skipped existing award: The Prisoner of Zenda (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Quality Street (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Snow White and the Seven Dwarfs (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Something to Sing About (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Souls at Sea (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Way Out West (1937), MUSIC (Scoring), winner: False
# Skipped existing award: Mr. Dodd Takes the Air (1937), MUSIC (Song), winner: False
# Skipped existing award: Waikiki Wedding (1937), MUSIC (Song), winner: True
# Skipped existing award: Walter Wanger's Vogues of 1938 (1937), MUSIC (Song), winner: False
# Skipped existing award: Shall We Dance (1937), MUSIC (Song), winner: False
# Skipped existing award: Artists and Models (1937), MUSIC (Song), winner: False
# Skipped existing award: The Awful Truth (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Captains Courageous (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Dead End (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Good Earth (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: In Old Chicago (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: The Life of Emile Zola (1937), OUTSTANDING PRODUCTION, winner: True
# Skipped existing award: Lost Horizon (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: One Hundred Men and a Girl (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Stage Door (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: A Star Is Born (1937), OUTSTANDING PRODUCTION, winner: False
# Skipped existing award: Educated Fish (1937), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Little Match Girl (1937), SHORT SUBJECT (Cartoon), winner: False
# Skipped existing award: The Old Mill (1937), SHORT SUBJECT (Cartoon), winner: True
# Skipped existing award: The Man without a Country (1937), SHORT SUBJECT (Color), winner: False
# Skipped existing award: Penny Wisdom (1937), SHORT SUBJECT (Color), winner: True
# Skipped existing award: Popular Science J-7-1 (1937), SHORT SUBJECT (Color), winner: False
# Skipped existing award: A Night at the Movies (1937), SHORT SUBJECT (One-reel), winner: False
# ...
# Skipping 'The Neighbors' Window', already enriched with metadata
# Skipping 'Saria', already enriched with metadata
# Updated 'A Sister' with TMDB ID 1153194
# Skipping 'Ad Astra', already enriched with metadata
# Skipping 'Avengers: Endgame', already enriched with metadata
# Skipping 'Knives Out', already enriched with metadata
# Skipping 'Sound of Metal', already enriched with metadata
# Skipping 'Ma Rainey's Black Bottom', already enriched with metadata
# Skipping 'The Father', already enriched with metadata
# Skipping 'Mank', already enriched with metadata
# Skipping 'Minari', already enriched with metadata
# Skipping 'The Trial of the Chicago 7', already enriched with metadata
# Skipping 'Judas and the Black Messiah', already enriched with metadata
# Skipping 'One Night in Miami...', already enriched with metadata
# Skipping 'The United States vs. Billie Holiday', already enriched with metadata
# Skipping 'Pieces of a Woman', already enriched with metadata
# Skipping 'Nomadland', already enriched with metadata
# Skipping 'Promising Young Woman', already enriched with metadata
# Skipping 'Borat Subsequent Moviefilm: Delivery of Prodigious Bribe to American Regime for Make Benefit Once Glorious Nation of Kazakhstan', already enriched with metadata
# Skipping 'Hillbilly Elegy', already enriched with metadata
# Skipping 'Onward', already enriched with metadata
# Skipping 'Over the Moon', already enriched with metadata
# Skipping 'A Shaun the Sheep Movie: Farmageddon', already enriched with metadata
# Skipping 'Soul', already enriched with metadata
# Skipping 'Wolfwalkers', already enriched with metadata
# Skipping 'News of the World', already enriched with metadata
# Skipping 'Another Round', already enriched with metadata
# Skipping 'Collective', already enriched with metadata
# Skipping 'Crip Camp', already enriched with metadata
# Skipping 'The Mole Agent', already enriched with metadata
# Skipping 'My Octopus Teacher', already enriched with metadata
# Skipping 'Time', already enriched with metadata
# Skipping 'Colette', already enriched with metadata
# Skipping 'A Concerto Is a Conversation', already enriched with metadata
# Skipping 'Do Not Split', already enriched with metadata
# Skipping 'Hunger Ward', already enriched with metadata
# Skipping 'A Love Song for Latasha', already enriched with metadata
# Skipping 'Better Days', already enriched with metadata
# Skipping 'The Man Who Sold His Skin', already enriched with metadata
# Skipping 'Quo Vadis, Aida?', already enriched with metadata
# Skipping 'Da 5 Bloods', already enriched with metadata
# Skipping 'Eurovision Song Contest: The Story of Fire Saga', already enriched with metadata
# Skipping 'The Life Ahead (La Vita Davanti a Se)', already enriched with metadata
# Skipping 'Tenet', already enriched with metadata
# Skipping 'Burrow', already enriched with metadata
# Skipping 'Genius Loci', already enriched with metadata
# Skipping 'If Anything Happens I Love You', already enriched with metadata
# Skipping 'Opera', already enriched with metadata
# Skipping 'Yes-People', already enriched with metadata
# Skipping 'Feeling Through', already enriched with metadata
# Skipping 'The Letter Room', already enriched with metadata
# Skipping 'The Present', already enriched with metadata
# Skipping 'Two Distant Strangers', already enriched with metadata
# Updated 'White Eye' with TMDB ID 1232736
# Skipping 'Greyhound', already enriched with metadata
# Skipping 'Love and Monsters', already enriched with metadata
# Skipping 'The Midnight Sky', already enriched with metadata
# Skipping 'The One and Only Ivan', already enriched with metadata
# Skipping 'The White Tiger', already enriched with metadata
# Skipping 'Being the Ricardos', already enriched with metadata
# Skipping 'The Power of the Dog', already enriched with metadata
# Skipping 'tick, tick...BOOM!', already enriched with metadata
# Skipping 'King Richard', already enriched with metadata
# Skipping 'The Tragedy of Macbeth', already enriched with metadata
# Skipping 'Belfast', already enriched with metadata
# Skipping 'CODA', already enriched with metadata
# Skipping 'The Eyes of Tammy Faye', already enriched with metadata
# Skipping 'The Lost Daughter', already enriched with metadata
# Skipping 'Parallel Mothers', already enriched with metadata
# Skipping 'Spencer', already enriched with metadata
# Skipping 'Encanto', already enriched with metadata
# Updated 'Flee' with TMDB ID 834104
# Skipping 'Luca', already enriched with metadata
# Skipping 'The Mitchells vs. the Machines', already enriched with metadata
# Skipping 'Raya and the Last Dragon', already enriched with metadata
# Skipping 'Nightmare Alley', already enriched with metadata
# Skipping 'Cruella', already enriched with metadata
# Skipping 'Cyrano', already enriched with metadata
# Skipping 'Drive My Car', already enriched with metadata
# Skipping 'Licorice Pizza', already enriched with metadata
# Skipping 'Ascension', already enriched with metadata
# Skipping 'Attica', already enriched with metadata
# Skipping 'Summer of Soul (...Or, When the Revolution Could Not Be Televised)', already enriched with metadata
# Skipping 'Writing with Fire', already enriched with metadata
# Skipping 'Audible', already enriched with metadata
# Skipping 'Lead Me Home', already enriched with metadata
# Skipping 'The Queen of Basketball', already enriched with metadata
# Skipping 'Three Songs for Benazir', already enriched with metadata
# Skipping 'When We Were Bullies', already enriched with metadata
# Skipping 'Don't Look Up', already enriched with metadata
# Skipping 'The Hand of God', already enriched with metadata
# Skipping 'Lunana: A Yak in the Classroom', already enriched with metadata
# Skipping 'The Worst Person in the World', already enriched with metadata
# Skipping 'Coming 2 America', already enriched with metadata
# Skipping 'House of Gucci', already enriched with metadata
# Skipping 'No Time to Die', already enriched with metadata
# Skipping 'Four Good Days', already enriched with metadata
# Skipping 'Affairs of the Art', already enriched with metadata
# Skipping 'Bestia', already enriched with metadata
# Skipping 'Boxballet', already enriched with metadata
# Skipping 'Robin Robin', already enriched with metadata
# Skipping 'The Windshield Wiper', already enriched with metadata
# Skipping 'Ala Kachuu - Take and Run', already enriched with metadata
# Updated 'The Dress' with TMDB ID 509804
# Skipping 'The Long Goodbye', already enriched with metadata
# Updated 'On My Mind' with TMDB ID 1025086
# Skipping 'Please Hold', already enriched with metadata
# Skipping 'Free Guy', already enriched with metadata
# Skipping 'Shang-Chi and the Legend of the Ten Rings', already enriched with metadata
# Skipping 'Spider-Man: No Way Home', already enriched with metadata
# Skipping 'Elvis', already enriched with metadata
# Skipping 'The Banshees of Inisherin', already enriched with metadata
# Skipping 'The Whale', already enriched with metadata
# Skipping 'Aftersun', already enriched with metadata
# Skipping 'Living', already enriched with metadata
# Skipping 'Causeway', already enriched with metadata
# Skipping 'The Fabelmans', already enriched with metadata
# Skipping 'Everything Everywhere All at Once', already enriched with metadata
# Skipping 'Tár', already enriched with metadata
# Skipping 'Blonde', already enriched with metadata
# Skipping 'To Leslie', already enriched with metadata
# Skipping 'Black Panther: Wakanda Forever', already enriched with metadata
# Skipping 'Guillermo del Toro's Pinocchio', already enriched with metadata
# Skipping 'Marcel the Shell with Shoes On', already enriched with metadata
# Skipping 'Puss in Boots: The Last Wish', already enriched with metadata
# Skipping 'The Sea Beast', already enriched with metadata
# Skipping 'Turning Red', already enriched with metadata
# Skipping 'Bardo, False Chronicle of a Handful of Truths', already enriched with metadata
# Skipping 'Empire of Light', already enriched with metadata
# Skipping 'Babylon', already enriched with metadata
# Skipping 'Mrs. Harris Goes to Paris', already enriched with metadata
# Skipping 'Triangle of Sadness', already enriched with metadata
# Skipping 'All That Breathes', already enriched with metadata
# Skipping 'All the Beauty and the Bloodshed', already enriched with metadata
# Skipping 'Fire of Love', already enriched with metadata
# Skipping 'A House Made of Splinters', already enriched with metadata
# Skipping 'Navalny', already enriched with metadata
# Skipping 'The Elephant Whisperers', already enriched with metadata
# Skipping 'Haulout', already enriched with metadata
# Skipping 'How Do You Measure a Year?', already enriched with metadata
# Skipping 'The Martha Mitchell Effect', already enriched with metadata
# Skipping 'Stranger at the Gate', already enriched with metadata
# Skipping 'Top Gun: Maverick', already enriched with metadata
# Skipping 'Argentina, 1985', already enriched with metadata
# Skipping 'Close', already enriched with metadata
# Skipping 'EO', already enriched with metadata
# Skipping 'The Quiet Girl', already enriched with metadata
# Skipping 'The Batman', already enriched with metadata
# Skipping 'Tell It like a Woman', already enriched with metadata
# Skipping 'RRR', already enriched with metadata
# Skipping 'Avatar: The Way of Water', already enriched with metadata
# Skipping 'Women Talking', already enriched with metadata
# Skipping 'The Boy, the Mole, the Fox and the Horse', already enriched with metadata
# Skipping 'The Flying Sailor', already enriched with metadata
# Skipping 'Ice Merchants', already enriched with metadata
# Skipping 'My Year of Dicks', already enriched with metadata
# Skipping 'An Ostrich Told Me the World Is Fake and I Think I Believe It', already enriched with metadata
# Skipping 'An Irish Goodbye', already enriched with metadata
# Skipping 'Ivalu', already enriched with metadata
# Skipping 'Le Pupille', already enriched with metadata
# Updated 'Night Ride' with TMDB ID 1301171
# Skipping 'The Red Suitcase', already enriched with metadata
# Skipping 'Glass Onion: A Knives Out Mystery', already enriched with metadata
# Skipping 'Welcome to Chechnya', already enriched with metadata
# Skipping 'Rustin', already enriched with metadata
# Skipping 'The Holdovers', already enriched with metadata
# Skipping 'Oppenheimer', already enriched with metadata
# Skipping 'American Fiction', already enriched with metadata
# Skipping 'Killers of the Flower Moon', already enriched with metadata
# Skipping 'Barbie', already enriched with metadata
# Skipping 'Poor Things', already enriched with metadata
# Skipping 'Nyad', already enriched with metadata
# Skipping 'Anatomy of a Fall', already enriched with metadata
# Skipping 'The Boy and the Heron', already enriched with metadata
# Skipping 'Elemental', already enriched with metadata
# Skipping 'Nimona', already enriched with metadata
# Skipping 'Robot Dreams', already enriched with metadata
# Skipping 'Spider-Man: Across the Spider-Verse', already enriched with metadata
# Skipping 'El Conde', already enriched with metadata
# Skipping 'Napoleon', already enriched with metadata
# Skipping 'The Zone of Interest', already enriched with metadata
# Skipping 'Bobi Wine: The People's President', already enriched with metadata
# Skipping 'The Eternal Memory', already enriched with metadata
# Skipping 'To Kill a Tiger', already enriched with metadata
# Skipping '20 Days in Mariupol', already enriched with metadata
# Skipping 'The ABCs of Book Banning', already enriched with metadata
# Skipping 'The Barber of Little Rock', already enriched with metadata
# Skipping 'Island in Between', already enriched with metadata
# Skipping 'The Last Repair Shop', already enriched with metadata
# Skipping 'Nai Nai & Wài Pó', already enriched with metadata
# Skipping 'Io Capitano', already enriched with metadata
# Skipping 'Perfect Days', already enriched with metadata
# Skipping 'Society of the Snow', already enriched with metadata
# Skipping 'The Teachers' Lounge', already enriched with metadata
# Skipping 'Golda', already enriched with metadata
# Skipping 'Indiana Jones and the Dial of Destiny', already enriched with metadata
# Skipping 'Flamin' Hot', already enriched with metadata
# Skipping 'American Symphony', already enriched with metadata
# Skipping 'Past Lives', already enriched with metadata
# Skipping 'Letter to a Pig', already enriched with metadata
# Skipping 'Ninety-Five Senses', already enriched with metadata
# Skipping 'Our Uniform', already enriched with metadata
# Skipping 'Pachyderme', already enriched with metadata
# Skipping 'WAR IS OVER! Inspired by the Music of John & Yoko', already enriched with metadata
# Skipping 'The After', already enriched with metadata
# Skipping 'Invincible', already enriched with metadata
# Skipping 'Knight of Fortune', already enriched with metadata
# Skipping 'Red, White and Blue', already enriched with metadata
# Skipping 'The Wonderful Story of Henry Sugar', already enriched with metadata
# Skipping 'The Creator', already enriched with metadata
# Skipping 'Mission: Impossible - Dead Reckoning Part One', already enriched with metadata
# Skipping 'Godzilla Minus One', already enriched with metadata
# Skipping 'Guardians of the Galaxy Vol. 3', already enriched with metadata
# Skipping 'May December', already enriched with metadata
# Skipping 'The Brutalist', already enriched with metadata
# Skipping 'A Complete Unknown', already enriched with metadata
# Skipping 'Sing Sing', already enriched with metadata
# Skipping 'Conclave', already enriched with metadata
# Skipping 'The Apprentice', already enriched with metadata
# Skipping 'Anora', already enriched with metadata
# Skipping 'A Real Pain', already enriched with metadata
# Skipping 'Wicked', already enriched with metadata
# Skipping 'Emilia Pérez', already enriched with metadata
# Skipping 'The Substance', already enriched with metadata
# Skipping 'I'm Still Here', already enriched with metadata
# Skipping 'Flow', already enriched with metadata
# Skipping 'Inside Out 2', already enriched with metadata
# Skipping 'Memoir of a Snail', already enriched with metadata
# Skipping 'Wallace & Gromit: Vengeance Most Fowl', already enriched with metadata
# Skipping 'The Wild Robot', already enriched with metadata
# Skipping 'Beautiful Men', already enriched with metadata
# Skipping 'In the Shadow of the Cypress', already enriched with metadata
# Skipping 'Magic Candies', already enriched with metadata
# Skipping 'Wander to Wonder', already enriched with metadata
# Updated 'Yuck!' with TMDB ID 1450824
# Skipping 'Dune: Part Two', already enriched with metadata
# Skipping 'Maria', already enriched with metadata
# Skipping 'Nosferatu', already enriched with metadata
# Skipping 'Gladiator II', already enriched with metadata
# Skipping 'Black Box Diaries', already enriched with metadata
# Skipping 'No Other Land', already enriched with metadata
# Skipping 'Porcelain War', already enriched with metadata
# Skipping 'Soundtrack to a Coup d'Etat', already enriched with metadata
# Skipping 'Sugarcane', already enriched with metadata
# Skipping 'Death by Numbers', already enriched with metadata
# Skipping 'I Am Ready, Warden', already enriched with metadata
# Skipping 'Incident', already enriched with metadata
# Skipping 'Instruments of a Beating Heart', already enriched with metadata
# Skipping 'The Only Girl in the Orchestra', already enriched with metadata
# Skipping 'The Girl with the Needle', already enriched with metadata
# Skipping 'The Seed of the Sacred Fig', already enriched with metadata
# Skipping 'A Different Man', already enriched with metadata
# Skipping 'The Six Triple Eight', already enriched with metadata
# Skipping 'Elton John: Never Too Late', already enriched with metadata
# Skipping 'Nickel Boys', already enriched with metadata
# Skipping 'A Lien', already enriched with metadata
# Skipping 'Anuja', already enriched with metadata
# Updated 'I'm Not a Robot' with TMDB ID 864433
# Skipping 'The Last Ranger', already enriched with metadata
# Skipping 'The Man Who Could Not Remain Silent', already enriched with metadata
# Skipping 'Alien: Romulus', already enriched with metadata
# Skipping 'Better Man', already enriched with metadata
# Skipping 'Kingdom of the Planet of the Apes', already enriched with metadata
# Skipping 'September 5', already enriched with metadata
#  Done enriching TMDB metadata.

# %% [markdown]
# ##  Step 3: Preview Data Inserted

# %%
from app import app, db
from models import Movie, OscarAward, Actor, Category

with app.app_context():
    print("Sample Movies:")
    for movie in Movie.query.limit(3).all():
        print(f" • {movie.title} ({movie.release_date})")

    print("\nSample Awards:")
    for award in OscarAward.query.limit(3).all():
        print(f" • {award.year_ceremony} — {award.category_id} — {award.film}")

    print("\nSample Actors:")
    for actor in Actor.query.limit(3).all():
        print(f" • {actor.name}")

    print("\nSample Categories:")
    for cat in Category.query.limit(3).all():
        print(f" • {cat.name}")
# Out:
# Using movies.db at: /Users/saba/Desktop/API/apiserver/movies.db
# Sample Movies:
#  • Star Wars (1977-05-25)
#  • Forrest Gump (1994-06-23)
#  • 9 Songs (2004-07-16)
#
# Sample Awards:
#  • 1928 — 1 — The Noose
#  • 1928 — 1 — The Patent Leather Kid
#  • 1928 — 1 — The Last Command
#
# Sample Actors:
#  • Richard Barthelmess
#  • Emil Jannings
#  • Louise Dresser
#
# Sample Categories:
#  • ACTOR
#  • ACTRESS
#  • ART DIRECTION
